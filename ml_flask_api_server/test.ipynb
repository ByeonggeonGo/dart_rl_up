# %%
from flask import Blueprint
import numpy as np
import pandas as pd
import pickle
import copy
from sklearn.preprocessing import MinMaxScaler
import requests
import pandas_datareader.data as web
import datetime

# %%
start = datetime.datetime(2016,1,1)
end = datetime.datetime(2022,2,22)

# %%
# https://finance.yahoo.com/quote/FB?p=FB&.tsrc=fin-srch 종목코드 참고
df = web.DataReader('^GSPC','yahoo',start,end)
df
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 2015-12-31  2062.540039  2043.619995  2060.590088  2043.939941  2655330000
# 2016-01-04  2038.199951  1989.680054  2038.199951  2012.660034  4304880000
# 2016-01-05  2021.939941  2004.170044  2013.780029  2016.709961  3706620000
# 2016-01-06  2011.709961  1979.050049  2011.709961  1990.260010  4336660000
# 2016-01-07  1985.319946  1938.829956  1985.319946  1943.089966  5076590000
# ...                 ...          ...          ...          ...         ...
# 2022-02-15  4472.770020  4429.279785  4429.279785  4471.069824  3363200000
# 2022-02-16  4489.549805  4429.680176  4455.750000  4475.009766  3478750000
# 2022-02-17  4456.060059  4373.810059  4456.060059  4380.259766  3596510000
# 2022-02-18  4394.600098  4327.220215  4384.569824  4348.870117  3871340000
# 2022-02-22  4362.120117  4267.109863  4332.740234  4304.759766  4007780000
#
#               Adj Close
# Date
# 2015-12-31  2043.939941
# 2016-01-04  2012.660034
# 2016-01-05  2016.709961
# 2016-01-06  1990.260010
# 2016-01-07  1943.089966
# ...                 ...
# 2022-02-15  4471.069824
# 2022-02-16  4475.009766
# 2022-02-17  4380.259766
# 2022-02-18  4348.870117
# 2022-02-22  4304.759766
#
# [1547 rows x 6 columns]

# %%
# economic_list = ['KOSPI200.KS','^GSPC','^N225',
# 'YM=F','ES=F','NQ=F','RTY=F','CL=F','GC=F',
# 'EURUSD=X','JPY=X',
# 'BTC-USD','NDAQ']

x_list_code = ['^GSPC','^N225',
'YM=F','ES=F','NQ=F','RTY=F','CL=F','GC=F',
'EURUSD=X','JPY=X',
'NDAQ']
y_code = "BTC-USD"

# %%
x_list = []
for i in x_list_code:
    print(i)
    df = web.DataReader(i,'yahoo',start,end)
    x_list.append(df)
y = web.DataReader(y_code,'yahoo',start,end)
# Out:
# ^GSPC
# ^N225
# YM=F
# ES=F
# NQ=F
# RTY=F
# CL=F
# GC=F
# EURUSD=X
# JPY=X
# NDAQ

# %%
# fig, axes = plt.subplots(12,1, figsize=(15,120))
# plt.subplot(2, 1, 1)  
# x_list[0]['Close'].plot()
# plt.subplot(2, 1, 2) 
# x_list[1]['Close'].plot()


for i,val in enumerate(x_list):
    a=plt.subplot(len(x_list),1,i+1)
    a.set_title(x_list_code[i])
    val['Close'].plot(figsize=(15,100))
